# %%
from tkinter import*
root=Tk()
root.title("MCQ TEST")
root.configure(bg="Mediumpurple1")

root.geometry("800x500")

label=Label(root,text="PYTHON PROGRAMMING TEST",bg="Mediumpurple1",font="Times 22 bold")
label.place(x=180,y=45)

e=Entry(root,width=50,bg="white")
e.place(x=248,y=150)

l2=Label(root,text=("ENTER YOUR REGISTERATION ID:"),bg="Mediumpurple1",font="Times 15 ")
l2.place(x=242,y=100)

def ins():
    root.destroy()
    inst=Tk()
    inst.title("Instructions")
    inst.configure(bg="white")
    inst.geometry("800x500")
    

    def begin():
        inst.destroy()
        one=Tk()
        one.title("Question 1")
        one.configure(bg="white")
        one.geometry("800x500")

        def q2():
            one.destroy()
            two=Tk()
            two.title("Question 2")
            two.configure(bg="white")
            two.geometry("800x500")

            def q3():
                two.destroy()
                three=Tk()
                three.title("Question 3")
                three.configure(bg="white")
                three.geometry("800x500")

                def q4():
                    three.destroy()
                    four=Tk()
                    four.title("Question 4")
                    four.configure(bg="white")
                    four.geometry("800x500")

                    def q5():
                        four.destroy()
                        five=Tk()
                        five.title("Question 5")
                        five.configure(bg="white")
                        five.geometry("800x500")

                        def res1():
                            five.destroy()
                            result=Tk()
                            result.title("RESULT")
                            result.configure(bg="white")
                            result.geometry("800x500")
                            m=0
                            co=0
                            k=[]
                            k9=[]
                            k8=[]
                            s=op2.get()
                            swap1=op1.get()
                            swap2=op3.get()
                            swap3=op4.get()
                            if s==1:
                                if swap1==0:
                                    if swap2==0:
                                        if swap3==0:
                                            m=m+3 
                                            co=co+1
                                        else:
                                            m=m-1
                                    else:
                                        m=m-1
                                else:
                                    m=m-1
                            elif s==0:
                                if swap1==0:
                                    if swap2==0:
                                        if swap3==0:
                                            m=m+0
                                        else:
                                            m=m-1
                                    else:
                                        m=m-1
                                else:
                                    m=m-1       
                            else:  
                                m=m-1
    
                            e=m
                            far=co
                            s1=op23.get()
                            nid1=op21.get()
                            nid2=op22.get()
                            nid3=op24.get()

                            if s1==1:
                                if nid1==0:
                                    if nid2==0:
                                        if nid3==0:
                                            e=e+3
                                            far=far+1
                                        else:
                                            e=e-1
                                    else:
                                        e=e-1
                                else:
                                    e=e-1
                            elif s1==0:
                                if nid1==0:
                                    if nid2==0:
                                        if nid3==0:
                                            e=e+0
                                        else:
                                            e=e-1
                                    else:
                                        e=e-1
                                else:
                                    e=e-1
                                
                            
                            else:
                                e=e-1
                            dur=far
                            f=e
                            s2=op32.get()
                            yuk1=op31.get()
                            yuk2=op33.get()
                            yuk3=op34.get()
                            if s2==1:
                                if yuk1==0:
                                    if yuk2==0:
                                        if yuk3==0:
                                            f=f+3
                                            dur=dur+1
                                        else:
                                            f=f-1
                                    else:
                                        f=f-1
                                else:
                                    f=f-1 
                            elif s2==0:
                                if yuk1==0:
                                    if yuk2==0:
                                        if yuk3==0:
                                            f=f+0
                                        else:
                                            f=f-1
                                    else:
                                        f=f-1
                                else:
                                    f=f-1
                                        
                            else:
                                f=f-1
                            
                            q=f
                            s3=op41.get()
                            s4=op42.get()
                            san1=op43.get()
                            san2=op44.get()
                            some=dur
                            if s3==1:
                                if s4==1:
                                    if san1==0:
                                        if san2==0:
                                            q=q+3
                                            some=some+1
                                        else:
                                            q=q-1
                                    else:
                                        q=q-1           
                                else:
                                    q=q-1
                                
                            elif s3==0:
                                    if s4==0:
                                        if san1==0:
                                            if san2==0:
                                                q=q+0
                                            else:
                                                q=q-1
                                        else:
                                            q=q-1
                                    else:
                                        q=q-1
                                        
                            else:
                                q=q-1
                           
                            h=q
                            s5=op53.get()
                            Til1=op51.get()
                            Til2=op52.get()
                            Til3=op54.get()
                            kaafi=some
                            thoda=5-kaafi
                            if s5==1:
                                if Til1==0:
                                    if Til2==0:
                                        if Til3==0:
                                            h=h+3
                                            kaafi=kaafi+1
                                        else:
                                            h=h-1
                                    else:
                                        h=h-1 
                                else:
                                    h=h-1
                            elif s5==0:
                                if Til1==0:
                                    if Til2==0:
                                        if Til3==0:
                                            h=h+0
                                        
                                        else:
                                            h=h-1
                                    else:
                                        h=h-1
                                else:
                                    h=h-1
                            else:
                                h=h-1
                            
                            k.append(h)
                            k9.append(kaafi)
                            k8.append(thoda)
                            fir=Label(text="NPPT-NATIONAL PYTHON PROGRAMMING TEST",bg="white",font="Times 22 bold").pack()
                            firs=Label(text="TOTAL MAXIMUM MARKS: 15",bg="white",font="Times 18 bold").pack()
                            le=Label(text="Score : ",bg="white",font="Times 30").place(x=300,y=200)
                            lf=Label(text=k,bg="white",font="Times 30").place(x=430,y=200)
                            sonal=Label(text="Number of questions answered correctly are:",bg="white",font="times 18").place(x=200,y=100)
                            monal=Label(text=k9,bg="white",font="Times 18").place(x=640,y=100)
                            Dipti=Label(text="Number of questions answered incorrectly are:",bg="white",font="times 18").place(x=200,y=150)
                            Ketaki=Label(text=k8,bg="white",font="times 18").place(x=660,y=150)
                            
                    
                        Q5=Label(five,text="Q5)Which can be an identifier?",bg="white",font="Times 30").pack()
                        op51=IntVar()
                        Checkbutton(five,text="1abc",bg="white",font="Times 25",variable=op51).place(x=325,y=50)
                        op52=IntVar()
                        Checkbutton(five,text="$121",bg="white",font="Times 25",variable=op52).place(x=325,y=100)
                        op53=IntVar()
                        Checkbutton(five,text="_xyl",bg="white",font="Times 25",variable=op53).place(x=325,y=150)
                        op54=IntVar()
                        Checkbutton(five,text="@python",bg="white",font="Times 25",variable=op54).place(x=325,y=200)
                        sub5=Button(five,text="SUBMIT ANSWER",bg="hot pink",command=res1).place(x=350,y=375)
                    


                                                
                    Q4=Label(four,text="Q4)Which of the following are control statements?",bg="white",font="Times 30").pack()
                    op41=IntVar()
                    Checkbutton(four,text="if",bg="white",font="Times 25",variable=op41).place(x=325,y=50)
                    op42=IntVar()
                    Checkbutton(four,text="while",bg="white",font="Times 25",variable=op42).place(x=325,y=100)
                    op43=IntVar()
                    Checkbutton(four,text="def",bg="white",font="Times 25",variable=op43).place(x=325,y=150)
                    op44=IntVar()
                    Checkbutton(four,text="@static method",bg="white",font="Times 25",variable=op44).place(x=325,y=200)
                    sub4=Button(four,text="SUBMIT ANSWER",bg="hot pink",command=q5).place(x=350,y=375)

                Q3=Label(three,text="Q3)Output of the bitwise operation 3&5 is: ",bg="white",font="Times 30").pack()
                op31=IntVar()
                Checkbutton(three,text="3",bg="white",font="Times 25",variable=op31).place(x=350,y=50)
                op32=IntVar()
                Checkbutton(three,text="1",bg="white",font="Times 25",variable=op32).place(x=350,y=100)
                op33=IntVar()
                Checkbutton(three,text="5",bg="white",font="Times 25",variable=op33).place(x=350,y=150)
                op34=IntVar()
                Checkbutton(three,text="7",bg="white",font="Times 25",variable=op34).place(x=350,y=200)
                sub3=Button(three,text="SUBMIT ANSWER",bg="hot pink",command=q4).place(x=350,y=375)

            Q2=Label(two,text="Q2)What does IDLE stand for?",bg="white",font="Times 30").pack()
            op21=IntVar()
            Checkbutton(two,text="Integrated Development Electronics",bg="white",font="Times 25",variable=op21).place(x=135,y=50)
            op22=IntVar()
            Checkbutton(two,text="Integrated Drive Environment",bg="white",font="Times 25",variable=op22).place(x=135,y=100)
            op23=IntVar()
            Checkbutton(two,text="Integrated Development Environment",bg="white",font="Times 25",variable=op23).place(x=135,y=150)
            op24=IntVar()
            Checkbutton(two,text=" None",bg="white",font="Times 25",variable=op24).place(x=135,y=200)
            sub2=Button(two,text="SUBMIT ANSWER",bg="hot pink",command=q3).place(x=350,y=375)

        Q1=Label(one,text="Q1)Who is the inventor of python language?",bg="white",font="Times 30").pack()
        op1=IntVar()
        Checkbutton(one,text="George Williams",bg="white",font="Times 25",variable=op1).place(x=275,y=50)
        op2=IntVar()
        Checkbutton(one,text="Van De Rossum",bg="white",font="Times 25",variable=op2).place(x=275,y=100)
        op3=IntVar()
        Checkbutton(one,text="William Shakesphere",bg="white",font="Times 25",variable=op3).place(x=275,y=150)
        op4=IntVar()
        Checkbutton(one,text="Elon Musk",bg="white",font="Times 25",variable=op4).place(x=275,y=200)
        sub1=Button(one,text="SUBMIT ANSWER",bg="hot pink",command=q2).place(x=350,y=375)
    
    moh1=Label(inst,text="INSTRUCTIONS",bg="turquoise",font="TIMES 50").pack()
    moh2=Label(inst,text="1.This test contains 5 questions.",bg="white",font="Times 20").pack()
    moh5=Label(inst,text="2.Attempt all the questions.",bg="white",font="Times 20").pack()
    moh3=Label(inst,text="3.All questions are multiple choice questions",bg="white",font="times 20").pack()
    moh5=Label(inst,text="4.Options given for a question are one or more than one correct. ",bg="white",font="Times 20").pack()
    moh4=Label(inst,text="5.Marking scheme is +3 for correct answer and -1 for incorrect answer.",bg="white",font="Times 20").pack()
    moh6=Label(inst,text="ALL THE BEST.",bg="white",font="Times 20").pack()
    stt=Button(inst,text="START EXAM",bg="hot pink",command=begin).place(x=350,y=375)
    


def start():
    z=e.get()
    c=int(z)
    if c == 181061010:
        l=Label(root,text="NAME:ANTARA BORKAR",bg="aquamarine2")
        l.place(x=320,y=250)
        m=Label(root,text="SUBJECT:PYTHON PROGRAMMING",bg="aquamarine2") 
        m.place(x=320,y=275)
        o=Label(root,text="TOTAL MARKS:15",bg="aquamarine2")
        o.place(x=320,y=300)
        x=Button(root,text="PROCEED TO INSTRUCTIOS",bg="hot pink",command=ins)
        x.place(x=320,y=350)
    else:
        i=Label(root,text=("INVALID ID!"),bg="white",fg="red",font="Times 10")
        i.place(x=325,y=250)
        d=Label(root,text=("ENTER AGAIN."),bg="white",fg="red",font="Times 10")
        d.place(x=325,y=275)
                    
b=Button(root,text="SUBMIT REGISTERATION ID",command=start,bg="hot pink",bd=1,relief="solid",font="Times 10",width=0,height=0)
b.place(x=310,y=200)

s=Scrollbar(root)
s.pack(side=RIGHT,fill=Y)


mainloop()
